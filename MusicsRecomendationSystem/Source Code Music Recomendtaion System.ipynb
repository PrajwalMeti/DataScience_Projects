# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns

# %%
music_df = pd.read_csv("Songs_DataList .csv")
music_df
# Out:
#        Unnamed: 0    artist_name  \
# 0               0   Arijit Singh
# 1               1   Arijit Singh
# 2               2   Arijit Singh
# 3               3   Arijit Singh
# 4               4  Jeet Gannguli
# ...           ...            ...
# 30896         995  K. J. Yesudas
# 30897         996  K. J. Yesudas
# 30898         997  K. J. Yesudas
# 30899         998  K. J. Yesudas
# 30900         999  K. J. Yesudas
#
#                                               track_name  \
# 0                    Sawan Aaya Hai (From "Creature 3D")
# 1        Kitni Haseen Hogi (From "Hit - The First Case")
# 2                                              Tum Hi Ho
# 3                            Hardum Humdum (From "Ludo")
# 4                     Arijit Singh Mashup (By DJ Paroma)
# ...                                                  ...
# 30896  Iru Meyyum (From "Njangal Santhushtaranu") - M...
# 30897                 Manju Nolkum Kalam (From "Megham")
# ...

# %%
music_df.shape
# Out:
# (30901, 24)

# %%
music_df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'track_id',
#        'track_popularity', 'artist_id', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
music_df.describe()
# Out:
#          Unnamed: 0  track_popularity  danceability        energy  \
# count  30901.000000      30901.000000  30863.000000  30863.000000
# mean     408.495421         23.468464      0.603708      0.591205
# std      267.678626         19.210118      0.152222      0.209999
# min        0.000000          0.000000      0.000000      0.000548
# 25%      178.000000          7.000000      0.501000      0.443000
# 50%      377.000000         20.000000      0.619000      0.605000
# 75%      620.000000         37.000000      0.717000      0.752000
# max      999.000000         95.000000      0.976000      1.000000
#
#                 key      loudness          mode   speechiness  acousticness  \
# count  30863.000000  30863.000000  30863.000000  30863.000000  30863.000000
# mean       5.338788     -8.552170      0.569906      0.079507      0.433525
# std        3.489366      4.123201      0.495097      0.092068      0.314796
# ...

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30901 entries, 0 to 30900
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        30901 non-null  int64
#  1   artist_name       30901 non-null  object
#  2   track_name        30901 non-null  object
#  3   track_id          30901 non-null  object
#  4   track_popularity  30901 non-null  int64
#  5   artist_id         30901 non-null  object
#  6   danceability      30863 non-null  float64
#  7   energy            30863 non-null  float64
#  8   key               30863 non-null  float64
#  9   loudness          30863 non-null  float64
#  10  mode              30863 non-null  float64
#  11  speechiness       30863 non-null  float64
#  12  acousticness      30863 non-null  float64
#  13  instrumentalness  30863 non-null  float64
#  14  liveness          30863 non-null  float64
#  15  valence           30863 non-null  float64
# ...

# %%
music_df[music_df.duplicated('track_name')]
# Out:
#        Unnamed: 0     artist_name  \
# 50             50    Arijit Singh
# 56             56          Pritam
# 73             73    Arijit Singh
# 87             87  Vishal-Shekhar
# 94             94     Jawad Ahmad
# ...           ...             ...
# 30879         978   K. J. Yesudas
# 30881         980   K. J. Yesudas
# 30892         991   K. J. Yesudas
# 30895         994   K. J. Yesudas
# 30900         999   K. J. Yesudas
#
#                                               track_name  \
# 50                                 Jaan 'Nisaar (Arijit)
# 56     Phir Na Aisi Raat Aayegi (From "Laal Singh Cha...
# 73                                              Ve Maahi
# 87                                 Ghungroo (From "War")
# 94                                             Samjhawan
# ...                                                  ...
# 30879                        Jumma Jumma (From "Brahma")
# 30881                Aa Poola Rangu (From "Dong Police")
# ...

# %%
music_df.drop_duplicates(subset='track_name',inplace = True)

# %%
music_df
# Out:
#        Unnamed: 0    artist_name  \
# 0               0   Arijit Singh
# 1               1   Arijit Singh
# 2               2   Arijit Singh
# 3               3   Arijit Singh
# 4               4  Jeet Gannguli
# ...           ...            ...
# 30894         993  K. J. Yesudas
# 30896         995  K. J. Yesudas
# 30897         996  K. J. Yesudas
# 30898         997  K. J. Yesudas
# 30899         998  K. J. Yesudas
#
#                                               track_name  \
# 0                    Sawan Aaya Hai (From "Creature 3D")
# 1        Kitni Haseen Hogi (From "Hit - The First Case")
# 2                                              Tum Hi Ho
# 3                            Hardum Humdum (From "Ludo")
# 4                     Arijit Singh Mashup (By DJ Paroma)
# ...                                                  ...
# 30894                  Premalokadinda (From "Premaloka")
# 30896  Iru Meyyum (From "Njangal Santhushtaranu") - M...
# ...

# %%
# Check for the Duplicate Records 
music_df[music_df.duplicated('track_name')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, artist_name, track_name, track_id, track_popularity, artist_id, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature]
# Index: []
#
# [0 rows x 24 columns]

# %%
music_df.isnull().sum()
# Out:
# Unnamed: 0           0
# artist_name          0
# track_name           0
# track_id             0
# track_popularity     0
# artist_id            0
# danceability        18
# energy              18
# key                 18
# loudness            18
# mode                18
# speechiness         18
# acousticness        18
# instrumentalness    18
# liveness            18
# valence             18
# tempo               18
# type                18
# id                  18
# uri                 18
# track_href          18
# analysis_url        18
# duration_ms         18
# time_signature      18
# dtype: int64

# %%
music_df.dropna(inplace = True)

# %%
music_df.isna().sum()
# Out:
# Unnamed: 0          0
# artist_name         0
# track_name          0
# track_id            0
# track_popularity    0
# artist_id           0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
music_df.drop(columns = ['Unnamed: 0','track_id','artist_id','type','id','uri','track_href','analysis_url'],inplace = True)

# %%
music_df
# Out:
#          artist_name                                         track_name  \
# 0       Arijit Singh                Sawan Aaya Hai (From "Creature 3D")
# 1       Arijit Singh    Kitni Haseen Hogi (From "Hit - The First Case")
# 2       Arijit Singh                                          Tum Hi Ho
# 3       Arijit Singh                        Hardum Humdum (From "Ludo")
# 4      Jeet Gannguli                 Arijit Singh Mashup (By DJ Paroma)
# ...              ...                                                ...
# 30894  K. J. Yesudas                  Premalokadinda (From "Premaloka")
# 30896  K. J. Yesudas  Iru Meyyum (From "Njangal Santhushtaranu") - M...
# 30897  K. J. Yesudas                 Manju Nolkum Kalam (From "Megham")
# 30898  K. J. Yesudas             Priyasakhee (From "Kaiethum Doorathu")
# 30899  K. J. Yesudas                                   Ahagu Ooviyamaka
#
#        track_popularity  danceability  energy   key  loudness  mode  \
# ...

# %%
# Graphycal Distirubution of the Features which can usefull for the model distrubution with respect to mode 
def frequency(col):
    plt.figure(figsize=(4,3))
    graph = sns.kdeplot(music_df[col][(music_df['mode'] == 1)],color = 'Green',shade = False)
    graph.set_xlabel(col)
    graph.set_ylabel('Frequency')
    plt.show()

# %%
frequency('track_popularity')
# Out:
# C:\Users\pbandi\AppData\Local\Temp\ipykernel_13408\1069436384.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   graph = sns.kdeplot(music_df[col][(music_df['mode'] == 1)],color = 'Green',shade = False)

# %%
frequency('energy')
# Out:
# C:\Users\pbandi\AppData\Local\Temp\ipykernel_13408\1069436384.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   graph = sns.kdeplot(music_df[col][(music_df['mode'] == 1)],color = 'Green',shade = False)

# %%
frequency('loudness')
# Out:
# C:\Users\pbandi\AppData\Local\Temp\ipykernel_13408\1069436384.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   graph = sns.kdeplot(music_df[col][(music_df['mode'] == 1)],color = 'Green',shade = False)

# %%
frequency('speechiness')
# Out:
# C:\Users\pbandi\AppData\Local\Temp\ipykernel_13408\1069436384.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   graph = sns.kdeplot(music_df[col][(music_df['mode'] == 1)],color = 'Green',shade = False)

# %%
# Finding the Best popular songs/ trackes by the Trackname and get the top 10 songs 
popular_songs = music_df.groupby('track_name')['track_popularity'].mean().sort_values(ascending=False).head(10)

# %%
popular_songs = music_df.groupby('track_name')['track_popularity'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(14,7))
plt.barh(popular_songs.index, popular_songs)
plt.title('Most Popular Songs/Tracks', fontdict=dict(fontsize=15), fontweight='bold')
plt.xlabel('Popularity', fontdict=dict(fontsize=15), fontweight='bold')
plt.ylabel('Song/Track Name', fontdict=dict(fontsize=15), fontweight='bold')
plt.xticks(fontsize='large', weight='bold')
plt.yticks(fontsize='large', weight='bold')
for i, v in enumerate(popular_songs):
    plt.text(v+0.5, i-0.15, str(int(v)), fontdict=dict(fontsize=15), fontweight='bold')
    
plt.show()

# %%
# Finding the Best popular songs/ trackes from by artist and get the top 10 songs 
popular_songs = music_df.groupby('artist_name')['track_popularity'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(14,7))
plt.barh(popular_songs.index, popular_songs)
plt.title('Most Popular Songs By Artist', fontdict=dict(fontsize=15), fontweight='bold')
plt.xlabel('Popularity', fontdict=dict(fontsize=15), fontweight='bold')
plt.ylabel('Artist Name', fontdict=dict(fontsize=15), fontweight='bold')
plt.xticks(fontsize='large', weight='bold')
plt.yticks(fontsize='large', weight='bold')
for i, v in enumerate(popular_songs):
    plt.text(v+0.5, i-0.15, str(int(v)), fontdict=dict(fontsize=15), fontweight='bold')
    
plt.show()

# %%
#model.building 
music_df.head()
# Out:
#      artist_name                                       track_name  \
# 0   Arijit Singh              Sawan Aaya Hai (From "Creature 3D")
# 1   Arijit Singh  Kitni Haseen Hogi (From "Hit - The First Case")
# 2   Arijit Singh                                        Tum Hi Ho
# 3   Arijit Singh                      Hardum Humdum (From "Ludo")
# 4  Jeet Gannguli               Arijit Singh Mashup (By DJ Paroma)
#
#    track_popularity  danceability  energy   key  loudness  mode  speechiness  \
# 0                 6         0.515   0.671  10.0    -7.510   0.0       0.1590
# 1                 0         0.473   0.473   8.0    -9.490   0.0       0.0333
# 2                70         0.528   0.449   5.0    -6.250   0.0       0.0250
# 3                 0         0.590   0.821   2.0    -4.933   1.0       0.0444
# 4                51         0.583   0.766   9.0    -5.142   0.0       0.0439
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
! pip install sweetviz
import sweetviz as sv

# %%
report = sv.analyze(music_df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
#Normalizing the data to get all the data in same scale for using Manhettan distance similarity for Recommending
def normalize_features(col):
    max_d = music_df[col].max()
    min_d = music_df[col].min()
    music_df[col] = ((music_df[col] - min_d)/(max_d - min_d))

# %%
# Normalize the Continious Variables
num_types = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num = music_df.select_dtypes(include = num_types)
for column in num.columns:
    normalize_features(column)

# %%
num.corr()
# Out:
#                   track_popularity  danceability    energy       key  \
# track_popularity          1.000000      0.044669  0.088588 -0.005672
# danceability              0.044669      1.000000  0.300865  0.015365
# energy                    0.088588      0.300865  1.000000  0.058591
# key                      -0.005672      0.015365  0.058591  1.000000
# loudness                  0.191743      0.190155  0.720472  0.021401
# mode                      0.001546     -0.046457 -0.090138 -0.146654
# speechiness              -0.088827      0.170554  0.062072  0.018811
# acousticness             -0.144695     -0.435831 -0.581813 -0.029765
# instrumentalness         -0.152975     -0.105979 -0.235512 -0.013299
# liveness                 -0.071516     -0.109704  0.117241  0.010696
# valence                  -0.111875      0.406207  0.390807  0.057317
# tempo                     0.005110     -0.042160  0.076870  0.010463
# duration_ms              -0.050096     -0.081064  0.037307 -0.003742
# ...
