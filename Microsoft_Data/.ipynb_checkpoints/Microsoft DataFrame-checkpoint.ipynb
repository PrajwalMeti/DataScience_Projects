# %%
import pandas as pd
import numpy as np
from scipy.stats import f_oneway

# %%
ms_df = pd.read_csv("Microsoft_data.csv")
ms_df
# Out:
#                       MachineIdentifier   ProductName EngineVersion  \
# 0      0000028988387b115f69f31a3bf04f09  win8defender   1.1.15100.1
# 1      000007535c3f730efa9ea0b7ef1bd645  win8defender   1.1.14600.4
# 2      000007905a28d863f6d0d597892cd692  win8defender   1.1.15100.1
# 3      00000b11598a75ea8ba1beea8459149f  win8defender   1.1.15100.1
# 4      000014a5f00daa18e76b81417eeb99fc  win8defender   1.1.15100.1
# ...                                 ...           ...           ...
# 51296  017bc14bd774c28eebdc5a76857477bf  win8defender   1.1.15200.1
# 51297  017bc19cca042fac9b858a702620bdd3  win8defender   1.1.15000.2
# 51298  017bc253c8342319c7cc28d978a7c9b3  win8defender   1.1.15100.1
# 51299  017bc3111b2719d5a59bc03a7528cc3e           mse   1.1.15100.1
# 51300  017bc4440fb9466e2fe33c9f22d8a96b  win8defender   1.1.15200.1
#
#             AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# 0      4.18.1807.18075  1.273.1735.0       0               7.0
# ...

# %%
# perform the below tasks on the Microsoft dataset:
# 1. Check for the count of missing values in each column.
# 2. Check for correlation of each input variable with the output(HasDetections).
# 3. Identify & Drop all the columns where each value is unique or all the  values are same.
# Out:
# 'MachineIdentifier'

# %%
# 1. Check for the count of missing values in each column.
Missing_values_in_each_column = ms_df.isnull().sum()

# %%
# 2. Check for correlation of each input variable with the output(HasDetections).
# Out:
# 51301

# %%
# Out:
# 51301
