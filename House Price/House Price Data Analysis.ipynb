# %%
# pandas is a libray which we can perform the analysis and having lacks of helper functions 
# Table in spread sheet or excel is called data fream in the Python 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hp_df = pd.read_csv('house_price_data.csv')
hp_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
hp_df.shape # Returns to  get the number of rows and columns in the Dataframe
# Out:
# (1460, 81)

# %%
x = hp_df.groupby(['MSZoning']).mean('SalePrice')
plt.boxplot(hp_df['SalePrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f1f35bed90>,
#   <matplotlib.lines.Line2D at 0x1f1f35bfad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f1f35c8710>,
#   <matplotlib.lines.Line2D at 0x1f1f35c9490>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f1f356b650>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f1f35c9f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f1f35caa50>],
#  'means': []}

# %%
hp_df.shape[1] # to get the columns in the data frame
# Out:
# 81

# %%
# to Access all the Columns in data frame
hp_df.columns  # Returns the Name of the columns from the Data Frame
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# To Access the particualar columns
hp_df['LotFrontage']  # Series[Equavlant to a column] to access the single column
hp_df[['MSZoning','LotArea','Street']] #To Access the multiple columns [ we have to pass like the list ] (Using the list) 
hp_df[['MSZoning','LotArea','Street']] # Access the multiple objects from the data frame
# Out:
#      MSZoning  LotArea Street
# 0          RL     8450   Pave
# 1          RL     9600   Pave
# 2          RL    11250   Pave
# 3          RL     9550   Pave
# 4          RL    14260   Pave
# ...       ...      ...    ...
# 1455       RL     7917   Pave
# 1456       RL    13175   Pave
# 1457       RL     9042   Pave
# 1458       RL     9717   Pave
# 1459       RL     9937   Pave
#
# [1460 rows x 3 columns]

# %%
hp_df.iloc[3:8,4:10]  # To access the particluar value [3:8] is the number of rows we are access from and to 
                      # [4:10] To access the number of columns from and to
# Out:
#   Street Alley LotShape LandContour Utilities LotConfig
# 3   Pave   NaN      IR1         Lvl    AllPub    Corner
# 4   Pave   NaN      IR1         Lvl    AllPub       FR2
# 5   Pave   NaN      IR1         Lvl    AllPub    Inside
# 6   Pave   NaN      Reg         Lvl    AllPub    Inside
# 7   Pave   NaN      IR1         Lvl    AllPub    Corner

# %%
hp_df.iloc[:3,:3]   # .iloc is used for the indexing in the Data Frame
# Out:
#    Id MSSubClass MSZoning
# 0   1         60       RL
# 1   2         20       RL
# 2   3         60       RL

# %%
hp_df[hp_df['SalePrice'] > 200000]   # Filter on the Data Frame  it will returns the all the recoreds where sales price greater than 200000
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 6            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 11           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1442         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1447         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1451         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 2         9   2008        WD         Normal     223500
# 4        12   2008        WD         Normal     250000
# 6         8   2007        WD         Normal     307000
# 11        7   2006       New        Partial     345000
# ...     ...    ...       ...            ...        ...
# 1442      4   2009        WD         Normal     310000
# 1447     12   2007        WD         Normal     240000
# 1451      5   2009       New        Partial     287090
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
#
# [427 rows x 81 columns]

# %%
# There are 2 variables in data science 1)Coninous variables -->  Real values or number 
# 2) Categorical Variables--> Enum fields in the BAAN 
hp_df['MSZoning'].value_counts()
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64

# %%
hp_df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
(hp_df['MSZoning'].value_counts())['FV']  # returns the all the
# Out:
# 65

# %%
hp_df['SalePrice'].describe() # Returns the Descriptve Statistics of continious variables
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
hp_df['SalePrice'].describe()['count'] # Returns the count in the statstics of the continious variables
# Out:
# 1460.0

# %%
hp_df.dtypes  # To know the data types of all the columns
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
hp_df[['SalePrice','MSZoning']].dtypes   # To indentify the particular data type of the columns 
hp_df['SalePrice'].dtypes
hp_df['MSZoning'].dtypes   # O Stnads for Objects 
#when ever the Data type is O or objects than it is a catagorical Objects
# Out:
# dtype('O')

# %%
hp_df['MSSubClass'].dtypes
# Out:
# dtype('int64')

# %%
# Convert the continious variables into catagorical variables and assign it to back to the Data Frame
hp_df['MSSubClass']=hp_df['MSSubClass'].astype(object)

# %%
hp_df['MSSubClass'].dtypes
# Out:
# dtype('O')

# %%
# Filter of the tYPE 2) Categorical Variables in the Data Frame 
hp_df[hp_df['MSZoning'] == 'RM']
# Out:
#         Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 8        9         50       RM         51.0     6120   Pave   NaN      Reg
# 15      16         45       RM         51.0     6120   Pave   NaN      Reg
# 21      22         45       RM         57.0     7449   Pave  Grvl      Reg
# 23      24        120       RM         44.0     4224   Pave   NaN      Reg
# 29      30         30       RM         60.0     6324   Pave   NaN      IR1
# ...    ...        ...      ...          ...      ...    ...   ...      ...
# 1428  1429         30       RM         60.0     7200   Pave   NaN      Reg
# 1438  1439         20       RM         90.0     7407   Pave   NaN      Reg
# 1441  1442        120       RM          NaN     4426   Pave   NaN      Reg
# 1449  1450        180       RM         21.0     1533   Pave   NaN      Reg
# 1452  1453        180       RM         35.0     3675   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 8            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 15           Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 21           Bnk    AllPub  ...        0    NaN  GdPrv         NaN       0
# 23           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 29           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1428         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1438         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1441         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1449         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1452         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 8         4   2008        WD        Abnorml     129900
# 15        7   2007        WD         Normal     132000
# 21        6   2007        WD         Normal     139400
# 23        6   2007        WD         Normal     129900
# 29        5   2008        WD         Normal      68500
# ...     ...    ...       ...            ...        ...
# 1428      2   2010        WD        Abnorml     119000
# 1438      4   2010        WD         Normal     149700
# 1441      5   2008        WD         Normal     149300
# 1449      8   2006        WD        Abnorml      92000
# 1452      5   2006        WD         Normal     145000
#
# [218 rows x 81 columns]

# %%
hp_df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
hp_df.sort_values(by = 'SalePrice',ascending = False)
# Out:
#         Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692         60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183         60       RL        160.0    15623   Pave   NaN      IR1
# 1169  1170         60       RL        118.0    35760   Pave   NaN      IR1
# 898    899         20       RL        100.0    12919   Pave   NaN      IR1
# 803    804         60       RL        107.0    13891   Pave   NaN      Reg
# ...    ...        ...      ...          ...      ...    ...   ...      ...
# 30      31         70  C (all)         50.0     8500   Pave  Pave      Reg
# 533    534         20       RL         50.0     5000   Pave   NaN      Reg
# 968    969         50       RM         50.0     5925   Pave   NaN      Reg
# 916    917         20  C (all)         50.0     9000   Pave   NaN      Reg
# 495    496         30  C (all)         60.0     7879   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 30           Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 533          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 968          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 916          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
# 1169      7   2006        WD         Normal     625000
# 898       3   2010       New        Partial     611657
# 803       1   2009       New        Partial     582933
# ...     ...    ...       ...            ...        ...
# 30        7   2008        WD         Normal      40000
# 533       1   2007        WD         Normal      39300
# 968       5   2009        WD        Abnorml      37900
# 916      10   2006        WD        Abnorml      35311
# 495      11   2009        WD        Abnorml      34900
#
# [1460 rows x 81 columns]

# %%
# returns all the sum of the missing values in the Data Frame of induival columns  
hp_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
hp_df.isnull().sum(axis = 1) # get the missing values count in each rows Axis = 1 is done by rows values axis = 0 done by column wise
# Out:
# 0       5
# 1       5
# 2       4
# 3       5
# 4       4
#        ..
# 1455    5
# 1456    3
# 1457    3
# 1458    6
# 1459    6
# Length: 1460, dtype: int64

# %%
# Filling the missing values using the .fillna and update that with the mean of the lot Frontage and assigned into the Data Frame

hp_df
# Out:
#         Id MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1         60       RL         65.0     8450   Pave   NaN      Reg
# 1        2         20       RL         80.0     9600   Pave   NaN      Reg
# 2        3         60       RL         68.0    11250   Pave   NaN      IR1
# 3        4         70       RL         60.0     9550   Pave   NaN      IR1
# 4        5         60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...        ...      ...          ...      ...    ...   ...      ...
# 1455  1456         60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457         20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458         70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459         20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460         20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
# Calculate the sum of the all the missing values in the particular column
hp_df['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
hp_df['LotFrontage'].fillna('Prajwal',inplace = True) # it was replaceing the all the empty values with the Prajwal

# %%
hp_df['LotFrontage'].isnull().sum() # To Calculate the all the data of the columns having null
# Out:
# 0

# %%
hp_df = hp_df.drop(columns = 'LotFrontage') # This is used to Delete a column from the Data Frame

# %%
hp_df
# Out:
#         Id MSSubClass MSZoning  LotArea Street Alley LotShape LandContour  \
# 0        1         60       RL     8450   Pave   NaN      Reg         Lvl
# 1        2         20       RL     9600   Pave   NaN      Reg         Lvl
# 2        3         60       RL    11250   Pave   NaN      IR1         Lvl
# 3        4         70       RL     9550   Pave   NaN      IR1         Lvl
# 4        5         60       RL    14260   Pave   NaN      IR1         Lvl
# ...    ...        ...      ...      ...    ...   ...      ...         ...
# 1455  1456         60       RL     7917   Pave   NaN      Reg         Lvl
# 1456  1457         20       RL    13175   Pave   NaN      Reg         Lvl
# 1457  1458         70       RL     9042   Pave   NaN      Reg         Lvl
# 1458  1459         20       RL     9717   Pave   NaN      Reg         Lvl
# 1459  1460         20       RL     9937   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0       AllPub    Inside  ...        0    NaN    NaN         NaN       0
# 1       AllPub       FR2  ...        0    NaN    NaN         NaN       0
# 2       AllPub    Inside  ...        0    NaN    NaN         NaN       0
# 3       AllPub    Corner  ...        0    NaN    NaN         NaN       0
# 4       AllPub       FR2  ...        0    NaN    NaN         NaN       0
# ...        ...       ...  ...      ...    ...    ...         ...     ...
# 1455    AllPub    Inside  ...        0    NaN    NaN         NaN       0
# 1456    AllPub    Inside  ...        0    NaN  MnPrv         NaN       0
# 1457    AllPub    Inside  ...        0    NaN  GdPrv        Shed    2500
# 1458    AllPub    Inside  ...        0    NaN    NaN         NaN       0
# 1459    AllPub    Inside  ...        0    NaN    NaN         NaN       0
#
#      MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0         2    2008        WD         Normal     208500
# 1         5    2007        WD         Normal     181500
# 2         9    2008        WD         Normal     223500
# 3         2    2006        WD        Abnorml     140000
# 4        12    2008        WD         Normal     250000
# ...     ...     ...       ...            ...        ...
# 1455      8    2007        WD         Normal     175000
# 1456      2    2010        WD         Normal     210000
# 1457      5    2010        WD         Normal     266500
# 1458      4    2010        WD         Normal     142125
# 1459      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %%
# Implimentation of apply functions 
def get_centure(year):
    if year > 2000:
        return '21st Century'
    elif year < 2000:
        return '20th Century'

# %%
hp_df['Century'] = hp_df['YearBuilt'].apply(get_centure)

# %%
# logorithum Calculations 
hp_df['LotArea']
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
hp_df['LotArea'].apply(np.log)
# Out:
# 0       9.041922
# 1       9.169518
# 2       9.328123
# 3       9.164296
# 4       9.565214
#           ...
# 1455    8.976768
# 1456    9.486076
# 1457    9.109636
# 1458    9.181632
# 1459    9.204020
# Name: LotArea, Length: 1460, dtype: float64

# %%
hp_df['LotArea']
# Out:
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# 1455     7917
# 1456    13175
# 1457     9042
# 1458     9717
# 1459     9937
# Name: LotArea, Length: 1460, dtype: int64

# %%
# Sale Price & Lot Area # Coefficiant co realtaion function is the function relation b/n 2 continues objects in the Data Frame 
# numpy self defined functions --> np.long To find the logarithum values 
#                              --> np.corrcoef
np.corrcoef(hp_df['SalePrice'],hp_df['LotArea'])
# Out:
# array([[1.        , 0.26384335],
#        [0.26384335, 1.        ]])

# %%
plt.boxplot(hp_df['SalePrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f1f36bb090>,
#   <matplotlib.lines.Line2D at 0x1f1f36bb990>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f1f36cc3d0>,
#   <matplotlib.lines.Line2D at 0x1f1f36ccc90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f1f35ea650>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f1f36cd550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f1f36cdd10>],
#  'means': []}

# %%
sns.boxplot(hp_df['SalePrice'])
# Out:
# <Axes: >

# %%
sns.distplot(hp_df['SalePrice'])
# Out:
# C:\Users\pbandi\AppData\Local\Temp\ipykernel_1172\2452045780.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp_df['SalePrice'])
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
plt.hist(hp_df['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
# Write a python functions that takes the columns (names ) from hp_df and retunrs a list of outlier values

# %%
sns.displot(hp_df['Utilities'])
# Out:
# C:\Users\pbandi\AppData\Local\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(hp_df['SalePrice'])
# Out:
# <Axes: >

# %%
hp_df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
hp_df.groupby('MSZoning').mean('SalePrice')
# Out:
#                   Id       LotArea  OverallQual  OverallCond    YearBuilt  \
# MSZoning
# C (all)   605.200000   9501.300000     3.900000     4.600000  1924.100000
# FV        707.030769   6638.861538     7.200000     5.030769  2004.507692
# RH        860.437500   7380.062500     5.250000     5.562500  1945.687500
# RL        737.277150  11571.814075     6.190269     5.535187  1975.461338
# RM        697.926606   6379.775229     5.454128     5.995413  1943.256881
#
#           YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2   BsmtUnfSF  ...  \
# MSZoning                                                                ...
# C (all)    1958.200000    0.000000  222.800000    0.000000  547.600000  ...
# FV         2004.830769  140.806452  327.892308    0.000000  663.123077  ...
# RH         1971.937500   57.812500  312.750000    8.687500  506.312500  ...
# RL         1985.659427  112.260908  492.514335   53.476108  569.921807  ...
# RM         1976.894495   56.169725  239.839450   28.770642  529.866972  ...
#
#           WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# MSZoning
# C (all)     9.800000    64.400000      82.500000   0.000000     9.900000
# FV         57.276923   103.476923       0.000000   0.000000     3.046154
# RH         67.625000    28.250000      58.687500   0.000000     0.000000
# RL        105.133797    45.141616      16.892268   4.192007    16.841877
# RM         53.600917    38.275229      49.752294   0.701835    10.582569
#
#           PoolArea    MiscVal    MoSold       YrSold      SalePrice
# MSZoning
# C (all)   0.000000  61.400000  7.700000  2008.300000   74528.000000
# FV        0.000000   0.000000  6.276923  2007.846154  214014.061538
# RH        0.000000   0.000000  7.500000  2007.500000  131558.375000
# RL        3.499566  47.749783  6.317116  2007.824500  191004.994787
# RM        0.000000  36.330275  6.211009  2007.761468  126316.830275
#
# [5 rows x 36 columns]

# %%
# Write a python functions that takes the columns (names) from hp_df and retunrs a list of outlier values

# Important Question in Interview 
def Calculate_outliers(col):
    q1 = (col.describe())['25%']
    q3 = (col.describe())['75%']
    iqr = q3 - q1
    hvo,lvo = [],[]
    for value in col:
        if value > q3 + (1.5* (iqr)):
            hvo.append(value)
        elif value < q1 - (1.5*(iqr)):
            lvo.append(value)
    total = [hvo,lvo]
    return total 
Calculate_outliers(hp_df['LotArea'])
# Out:
# [[50271,
#   19900,
#   21000,
#   21453,
#   19378,
#   31770,
#   22950,
#   25419,
#   159000,
#   19296,
#   39104,
#   19138,
#   18386,
#   215245,
#   164660,
#   20431,
#   18800,
#   53107,
#   34650,
#   22420,
#   21750,
#   70761,
#   53227,
#   40094,
#   32668,
#   21872,
#   21780,
#   25095,
#   46589,
#   20896,
#   18450,
#   21535,
#   26178,
#   115149,
#   21695,
#   53504,
#   21384,
#   28698,
#   45600,
#   17920,
#   25286,
#   27650,
#   24090,
#   25000,
#   21286,
#   21750,
#   29959,
#   18000,
#   23257,
#   17755,
#   35760,
#   18030,
#   35133,
#   32463,
#   18890,
#   24682,
#   23595,
#   17871,
#   36500,
#   63887,
#   20781,
#   25339,
#   57200,
#   20544,
#   19690,
#   21930,
#   26142],
#  [1300, 1477]]

# %%
# Manohar's Method to calculate-->
#the write a python functions that takes the columns (names) from hp_df and retunrs a list of outlier values
# Important Question in Interview 

def get_outliers(col):
    q1 = (hp_df[col].describe())['25%']
    q3 = (hp_df[col].describe())['75%']
    iqr = q3 - q1 
    return [val for val in hp_df[col] if val > q3 + (1.5*iqr)],[val for val in hp_df[col] if val < q1 - (1.5*iqr)]
get_outliers('LotArea')
# Out:
# ([50271,
#   19900,
#   21000,
#   21453,
#   19378,
#   31770,
#   22950,
#   25419,
#   159000,
#   19296,
#   39104,
#   19138,
#   18386,
#   215245,
#   164660,
#   20431,
#   18800,
#   53107,
#   34650,
#   22420,
#   21750,
#   70761,
#   53227,
#   40094,
#   32668,
#   21872,
#   21780,
#   25095,
#   46589,
#   20896,
#   18450,
#   21535,
#   26178,
#   115149,
#   21695,
#   53504,
#   21384,
#   28698,
#   45600,
#   17920,
#   25286,
#   27650,
#   24090,
#   25000,
#   21286,
#   21750,
#   29959,
#   18000,
#   23257,
#   17755,
#   35760,
#   18030,
#   35133,
#   32463,
#   18890,
#   24682,
#   23595,
#   17871,
#   36500,
#   63887,
#   20781,
#   25339,
#   57200,
#   20544,
#   19690,
#   21930,
#   26142],
#  [1300, 1477])

# %%
# Group by using the Pandas   
hp_df.groupby('MSZoning').mean('SalePrice')      # To Access for all the Data
# Out:
#                   Id       LotArea  OverallQual  OverallCond    YearBuilt  \
# MSZoning
# C (all)   605.200000   9501.300000     3.900000     4.600000  1924.100000
# FV        707.030769   6638.861538     7.200000     5.030769  2004.507692
# RH        860.437500   7380.062500     5.250000     5.562500  1945.687500
# RL        737.277150  11571.814075     6.190269     5.535187  1975.461338
# RM        697.926606   6379.775229     5.454128     5.995413  1943.256881
#
#           YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2   BsmtUnfSF  ...  \
# MSZoning                                                                ...
# C (all)    1958.200000    0.000000  222.800000    0.000000  547.600000  ...
# FV         2004.830769  140.806452  327.892308    0.000000  663.123077  ...
# RH         1971.937500   57.812500  312.750000    8.687500  506.312500  ...
# RL         1985.659427  112.260908  492.514335   53.476108  569.921807  ...
# RM         1976.894495   56.169725  239.839450   28.770642  529.866972  ...
#
#           WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# MSZoning
# C (all)     9.800000    64.400000      82.500000   0.000000     9.900000
# FV         57.276923   103.476923       0.000000   0.000000     3.046154
# RH         67.625000    28.250000      58.687500   0.000000     0.000000
# RL        105.133797    45.141616      16.892268   4.192007    16.841877
# RM         53.600917    38.275229      49.752294   0.701835    10.582569
#
#           PoolArea    MiscVal    MoSold       YrSold      SalePrice
# MSZoning
# C (all)   0.000000  61.400000  7.700000  2008.300000   74528.000000
# FV        0.000000   0.000000  6.276923  2007.846154  214014.061538
# RH        0.000000   0.000000  7.500000  2007.500000  131558.375000
# RL        3.499566  47.749783  6.317116  2007.824500  191004.994787
# RM        0.000000  36.330275  6.211009  2007.761468  126316.830275
#
# [5 rows x 36 columns]

# %%
# we have to use the Group by for the Catagorical variables 
hp_df[hp_df['MSZoning'] == 'RL']['SalePrice'].mean()
# Out:
# 191004.99478714162

# %%
# Group by using the Pandas   
hp_df.groupby('MSZoning').mean('SalePrice')['SalePrice']      # To Access for all the Data
# Out:
# MSZoning
# C (all)     74528.000000
# FV         214014.061538
# RH         131558.375000
# RL         191004.994787
# RM         126316.830275
# Name: SalePrice, dtype: float64

# %%
hp_df.drop(columns = ['MSSubClass','MSZoning'])
# Out:
#         Id  LotArea Street Alley LotShape LandContour Utilities LotConfig  \
# 0        1     8450   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1        2     9600   Pave   NaN      Reg         Lvl    AllPub       FR2
# 2        3    11250   Pave   NaN      IR1         Lvl    AllPub    Inside
# 3        4     9550   Pave   NaN      IR1         Lvl    AllPub    Corner
# 4        5    14260   Pave   NaN      IR1         Lvl    AllPub       FR2
# ...    ...      ...    ...   ...      ...         ...       ...       ...
# 1455  1456     7917   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1456  1457    13175   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1457  1458     9042   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1458  1459     9717   Pave   NaN      Reg         Lvl    AllPub    Inside
# 1459  1460     9937   Pave   NaN      Reg         Lvl    AllPub    Inside
#
#      LandSlope Neighborhood  ... PoolQC  Fence MiscFeature MiscVal  MoSold  \
# 0          Gtl      CollgCr  ...    NaN    NaN         NaN       0       2
# 1          Gtl      Veenker  ...    NaN    NaN         NaN       0       5
# 2          Gtl      CollgCr  ...    NaN    NaN         NaN       0       9
# 3          Gtl      Crawfor  ...    NaN    NaN         NaN       0       2
# 4          Gtl      NoRidge  ...    NaN    NaN         NaN       0      12
# ...        ...          ...  ...    ...    ...         ...     ...     ...
# 1455       Gtl      Gilbert  ...    NaN    NaN         NaN       0       8
# 1456       Gtl       NWAmes  ...    NaN  MnPrv         NaN       0       2
# 1457       Gtl      Crawfor  ...    NaN  GdPrv        Shed    2500       5
# 1458       Gtl        NAmes  ...    NaN    NaN         NaN       0       4
# 1459       Gtl      Edwards  ...    NaN    NaN         NaN       0       6
#
#       YrSold  SaleType  SaleCondition SalePrice       Century
# 0       2008        WD         Normal    208500  21st Century
# 1       2007        WD         Normal    181500  20th Century
# 2       2008        WD         Normal    223500  21st Century
# 3       2006        WD        Abnorml    140000  20th Century
# 4       2008        WD         Normal    250000          None
# ...      ...       ...            ...       ...           ...
# 1455    2007        WD         Normal    175000  20th Century
# 1456    2010        WD         Normal    210000  20th Century
# 1457    2010        WD         Normal    266500  20th Century
# 1458    2010        WD         Normal    142125  20th Century
# 1459    2008        WD         Normal    147500  20th Century
#
# [1460 rows x 79 columns]

# %%
"""
     Chi-Square Test :--> It is Hypothysis Test --> To Test the Corelation Betweeen two Catagorical Varaible 
    Steps for Hypothysis
    
    1.  Null Hypothysis :No Corelation exist between the two Variables .
    2. Alternate Hypothysis : Corelation Exist.
    3. Confidence Level =  0.95  and Significance Level  = 1- 0.95 = 0.05
    4. Collect the evidence 
    5. Calculate the chi -2 test stastics & P -value 
    6. Conclude : if p -values  from step(5) < significance level (0.05 ), Reject H0,
                  if p -values from steup(5) > Significance level (0.05), Fail to Reject H0,
    
"""
# Out:
# '\n     Chi-Square Test :--> It is Hypothysis Test --> To Test the Corelation Betweeen two Catagorical Varaible \n    Steps for Hypothysis\n    \n    1.  Null Hypothysis :No Corelation exist between the two Variables .\n    2. Alternate Hypothysis : Corelation Exist.\n    3. Confidence Level =  0.95  and Significance Level  = 1- 0.95 = 0.05\n    4. Collect the evidence \n    5. Calculate the chi -2 test stastics & P -value \n    6. Conclude : if p -values  from step(5) < significance level (0.05 ), Reject H0,\n                  if p -values from steup(5) > Significance level (0.05), Fail to Reject H0,\n    \n'

# %%
hp_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice',
#        'Century'],
#       dtype='object')

# %%
################## Date 26/11/2023 ****************************************************************************
# Chi-Squaire and Anova 
# 1. Chi-squair Test 

""" 
    Corelation check between MSZoing and LotShape (From hp_df) Dataframe
    
    Chi-Square Test :--> It is Hypothysis Test --> To Test the Corelation Betweeen two Catagorical Varaible 
    
    Steps for Hypothysis.
    1. Null Hypothysis (H0):No Corelation exist between the two Variables .
    2. Alternate Hypothysis (HA) : it is opposite of Hypothysis
    3. Set up the Confidence level 
        Confidence level = 0.95 , Significance Level = 1 - 0.95 = 0.05 
    4. Collect the Evidence 
    5. Calculate the chi-2 Test Statistics & P- Values 
    6. Conclude:  if p -values  from step(5) < significance level (0.05 ), Reject H0, Corelated
                  if p -values from steup(5) > Significance level (0.05), Fail to Reject H0, Not Corelated  
    
"""
# Out:
# ' \n    Corelation check between MSZoing and LotShape (From hp_df) Dataframe\n    \n    Chi-Square Test :--> It is Hypothysis Test --> To Test the Corelation Betweeen two Catagorical Varaible \n    \n    Steps for Hypothysis.\n    1. Null Hypothysis (H0):No Corelation exist between the two Variables .\n    2. Alternate Hypothysis (HA) : it is opposite of Hypothysis\n    3. Set up the Confidence level \n        Confidence level = 0.95 , Significance Level = 1 - 0.95 = 0.05 \n    4. Collect the Evidence \n    5. Calculate the chi-2 Test Statistics & P- Values \n    6. Conclude:  if p -values  from step(5) < significance level (0.05 ), Reject H0, Corelated\n                  if p -values from steup(5) > Significance level (0.05), Fail to Reject H0, Not Corelated  \n    \n'

# %%
# Chi-2 Test we will use for the 2 catogorical variables 
# Corelation check between MSZoing and LotShape (From hp_df) Dataframe
# for this we have to import the helper function from scipy library

# %%
# Scipy.stats 
from scipy.stats import chi2_contingency
# It was used to get the Observed Table of 2 Catogorical dataframe 
observed_table = pd.crosstab(hp_df['MSZoning'],hp_df['LotShape'])  
chi2_contingency(observed_table)
p_value =chi2_contingency(observed_table)[1]
p_value # 0.00000000000000000001359 < 0.05   Reject the Null Hypothysis, There for these 2 variables are Correlated.
# Out:
# 1.3596271487657125e-18

# %%
# Degree of Freedom (DOF)
# For N Number of stundents N-1 students having the Freedom to choose the Number

# %%
# MSZoning --> Catogorical Variable 
# Write a logic to check corelation between MSZoning and Other Catogorical Variables From hp_df  
# My Solution 
Catogorical_Variables = hp_df.select_dtypes(include="object")
List_of_Catogorical  =Catogorical_Variables.columns
def all_catogrical_corellated_varaibles(List_of_Catogorical):
    correlated_varaibles = []
    for each_variable in List_of_Catogorical:
        observed_table = pd.crosstab(hp_df['MSZoning'],hp_df[each_variable])
        chi2_contingency(observed_table)
        p_value = chi2_contingency(observed_table)[1]
        if p_value < 0.05:
            correlated_varaibles.append(each_variable)
    return correlated_varaibles
all_catogrical_corellated_varaibles(List_of_Catogorical)
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition',
#  'Century']

# %%
# MSZoning --> Catogorical Variable 
# Write a logic to check corelation between MSZoning and Other Catogorical Variables From hp_df  
# Mentor Method --> Manohar Method 
cat_col = [col for col in hp_df.columns if hp_df[col].dtype == 'object']
for col in cat_col:
    observed_tables = pd.crosstab(hp_df['MSZoning'],hp_df[col])
    if chi2_contingency(observed_tables)[1] < 0.05:
        print(col)
# Out:
# MSSubClass
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# Exterior1st
# Exterior2nd
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# SaleType
# SaleCondition
# Century

# %%
# Correlation Between MZZooming( Catogorical Variable) & Sales Price 
hp_df
# Out:
#         Id MSSubClass MSZoning  LotArea Street Alley LotShape LandContour  \
# 0        1         60       RL     8450   Pave   NaN      Reg         Lvl
# 1        2         20       RL     9600   Pave   NaN      Reg         Lvl
# 2        3         60       RL    11250   Pave   NaN      IR1         Lvl
# 3        4         70       RL     9550   Pave   NaN      IR1         Lvl
# 4        5         60       RL    14260   Pave   NaN      IR1         Lvl
# ...    ...        ...      ...      ...    ...   ...      ...         ...
# 1455  1456         60       RL     7917   Pave   NaN      Reg         Lvl
# 1456  1457         20       RL    13175   Pave   NaN      Reg         Lvl
# 1457  1458         70       RL     9042   Pave   NaN      Reg         Lvl
# 1458  1459         20       RL     9717   Pave   NaN      Reg         Lvl
# 1459  1460         20       RL     9937   Pave   NaN      Reg         Lvl
#
#      Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal MoSold YrSold  \
# 0       AllPub    Inside  ...    NaN    NaN         NaN       0      2   2008
# 1       AllPub       FR2  ...    NaN    NaN         NaN       0      5   2007
# 2       AllPub    Inside  ...    NaN    NaN         NaN       0      9   2008
# 3       AllPub    Corner  ...    NaN    NaN         NaN       0      2   2006
# 4       AllPub       FR2  ...    NaN    NaN         NaN       0     12   2008
# ...        ...       ...  ...    ...    ...         ...     ...    ...    ...
# 1455    AllPub    Inside  ...    NaN    NaN         NaN       0      8   2007
# 1456    AllPub    Inside  ...    NaN  MnPrv         NaN       0      2   2010
# 1457    AllPub    Inside  ...    NaN  GdPrv        Shed    2500      5   2010
# 1458    AllPub    Inside  ...    NaN    NaN         NaN       0      4   2010
# 1459    AllPub    Inside  ...    NaN    NaN         NaN       0      6   2008
#
#       SaleType  SaleCondition  SalePrice       Century
# 0           WD         Normal     208500  21st Century
# 1           WD         Normal     181500  20th Century
# 2           WD         Normal     223500  21st Century
# 3           WD        Abnorml     140000  20th Century
# 4           WD         Normal     250000          None
# ...        ...            ...        ...           ...
# 1455        WD         Normal     175000  20th Century
# 1456        WD         Normal     210000  20th Century
# 1457        WD         Normal     266500  20th Century
# 1458        WD         Normal     142125  20th Century
# 1459        WD         Normal     147500  20th Century
#
# [1460 rows x 81 columns]

# %%
from scipy.stats import f_oneway
RL_list = hp_df[hp_df['MSZoning'] == 'RL']['SalePrice']
RM_list = hp_df[hp_df['MSZoning'] == 'RM']['SalePrice']
FV_list = hp_df[hp_df['MSZoning'] == 'FV']['SalePrice']
RH_list = hp_df[hp_df['MSZoning'] == 'R']['SalePrice']
C_all_list = hp_df[hp_df['MSZoning'] == 'C (all)']['SalePrice']

# %%
f_oneway(RL_list,RM_list,FV_list,RH_list,C_all_list)
# Out:
# C:\Users\pbandi\AppData\Local\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4133: DegenerateDataWarning: at least one input has length 0
#   warnings.warn(stats.DegenerateDataWarning('at least one input '
# F_onewayResult(statistic=nan, pvalue=nan)

# %%
# Variance Between Groups / Variance within Groups 
hp_df['SalePrice'].mean()
# Out:
# 180921.19589041095

# %%
RL_mean = hp_df[hp_df['MSZoning'] == 'RL']['SalePrice'].mean()  # RL 
RM_list = hp_df[hp_df['MSZoning'] == 'RM']['SalePrice'].mean()  # RM 
FV_list = hp_df[hp_df['MSZoning'] == 'FV']['SalePrice'].mean()  # FV
RH_list = hp_df[hp_df['MSZoning'] == 'RH']['SalePrice'].mean()  # RH 
C_all_list = hp_df[hp_df['MSZoning'] == 'C (all)']['SalePrice'].mean() # CAll

# %%
# Varuabce  Between the Groups 
print((hp_df['SalePrice'].mean() - hp_df[hp_df['MSZoning'] == 'RL']['SalePrice'].mean())** 2 + 
((hp_df['SalePrice'].mean() - hp_df[hp_df['MSZoning'] == 'RM']['SalePrice'].mean())** 2  +
(hp_df['SalePrice'].mean() - hp_df[hp_df['MSZoning'] == 'FV']['SalePrice'].mean())** 2  +
(hp_df['SalePrice'].mean() - hp_df[hp_df['MSZoning'] == 'RH']['SalePrice'].mean())** 2 +
(hp_df['SalePrice'].mean() - hp_df[hp_df['MSZoning'] == 'C (all)']['SalePrice'].mean())** 2))
x =  180921.19589041095 /17934657719.26021
x
# Out:
# 17934657719.26021
# 1.0087797532713315e-05

# %%
# WAPF That takes a categorical variable (from hp_df) and check for the correlation with salePrice.
#sample_input = 'MSZoning'
#sample_output = 'Correlated'
def annva(col):
    categories = list(hp_df[col].value_counts().index)
    p_value = f_oneway(*[hp_df[hp_df[col] == cat]['SalePrice'] for cat in categories])[1]
    
    if p_value < 0.05:
        return 'Correlated'
    else:
        return 'Not Correlated'
annva('MSZoning')
# hp_df['MSZoning'].values_counts().index
# Out:
# 'Correlated'

# %%
list(hp_df['MSZoning'].value_counts().index)
# Out:
# ['RL', 'RM', 'FV', 'RH', 'C (all)']

# %%
# WAPF That takes a input from the and check with the output sales price and return correlated or not 

def anova(col):
    Correlated = []
    x = hp_df.select_dtypes(include="object")
    for columns in x:
        categories = list(hp_df[columns].value_counts().index)
        p_value = f_oneway(*[hp_df[hp_df[col] == cat]['SalePrice'] for cat in categories])[1]

        Correlated.append(p_value)
    return Correlated
z = anova(x)
list(zip(x,z))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1.0087797532713315e-05
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 12
#      10         Correlated.append(p_value)
#      11     return Correlated
# ---> 12 z = anova(x)
#      13 list(zip(x,z))
#
# Cell In[70], line 8, in anova(col)
#       6 for columns in x:
#       7     categories = list(hp_df[columns].value_counts().index)
# ----> 8     p_value = f_oneway(*[hp_df[hp_df[col] == cat]['SalePrice'] for cat in categories])[1]
#      10     Correlated.append(p_value)
#      11 return Correlated
#
# Cell In[70], line 8, in <listcomp>(.0)
#       6 for columns in x:
#       7     categories = list(hp_df[columns].value_counts().index)
# ----> 8     p_value = f_oneway(*[hp_df[hp_df[col] == cat]['SalePrice'] for cat in categories])[1]
#      10     Correlated.append(p_value)
#      11 return Correlated
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 1.0087797532713315e-05

# %%
# WAPF That takes a input from the and check with the output sales price and return correlated or not
col = hp_df.select_dtypes(include="object")
col = col.columns
def anova(col):
    Correlated = []
    for columns in col:
        categories = list(hp_df[columns].value_counts().index)
        p_value = f_oneway(*[hp_df[hp_df[columns] == cat]['SalePrice'] for cat in categories])[1]
        if p_value < 0.05:
            Correlated.append('Correlated')
        else:
            Correlated.append('Not Correlated')
    return Correlated
anova(col)
list(zip(col,anova(col)))
categories

# %%
# Write a logic to Create a DataFrame 3 Columns 
MSZoning    NA Count 0     NA Count % 
MSSbuclass    100 
LOt Frontage

# %%
# Prajju = pb.DataFrame(hp_df.columns,columns = )
x = hp_df.columns
Pr_df = pd.DataFrame(x,columns =['Description'])
Pr_df = pd.DataFrame(hp_df.isnull().sum(axis = 0),columns = ['No of Missing values'])
# Pr_df = 
Pr_df

# %%
def percentage_of_null_values_in_each_column(No_of_rows,Null_values_in_each_column):
    percentage = []
    for i in x:
        percentage.append((i/No_of_rows)* 100)
    return percentage
Percentage_each_column = percentage_of_null_values_in_each_column(hp_df.shape[0],Pr_df['No of Missing values'])

# %%
hp_df.isnull().sum(axis = 0)

# %%
# 31-12-2023   # Learn about the Scaling 1.Standards Scalre

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,LabelEncoder,OneHotEncoder

# %%
hp_df = pd.read_csv('house_price_data.csv')

# %%
# Standard Scaltred We should not apply the Stnadard Scler 
# In Numpy array if you want to choose give the numpy to decide the array shapre  then give it as -1 
std_scaler = StandardScaler()

std_scaled_values = std_scaler.fit_transform(np.array(hp_df['LotArea']).reshape(-1,1))
std_scaled_values   # 0 = mean and the 1 Variance and standard deviation is 1

# %%
min_max_scaler = MinMaxScaler()
min_max_scaler_values = min_max_scaler.fit_transform(np.array(hp_df['LotArea']).reshape(-1,1))
min_max_scaler_values.std()   # each Scaled Values between the 0 and 1

# %%
for column in hp_df.columns:
    if hp_df[column].dtype == 'int64'or hp_df[column].dtype == 'float64':
        hp_df[column] = std_scaler.fit_transform(np.array(hp_df[column]).reshape(-1,1))
hp_df

# %%
# For the Catogorical Techniques there are 2 types of 
# Encoding Technique are there 
#    1. One-Hot Encoding 
#    2. Label Encoding

# %%
hp_df['MSZoning'].value_counts()

# %%
oe_mszoning = pd.get_dummies(hp_df['MSZoning'])    # One-hot Encoding 

oe_mszoning.replace({True:1,False:0})

# %%
# Draw-back of One-hot Encoading 
# the thing is if 1000 unique values count is availabel in the Data set then we have to perfrom the 1000-1 = 999 columns

# %%
# 2nd Encoading 
# Label Encoading 
le = LabelEncoder()
le.fit_transform(hp_df['MSZoning'])
# le.inverse_transform([3,2,1,0])
le.transform(hp_df['MSZoning'])

# %%
oneHotencod = OneHotEncoder()
oneHotencod.fit_transform(np.array(hp_df['MSZoning']).reshape(-1,1))
oneHotencod

# %%
# Multi Co-linearity --> Co-relation betweent the input amoung the models
