# %%
import pandas as pd 
import numpy as np 
from scipy.stats import chi2_contingency,f_oneway

# %%
hp_df = pd.read_csv('house_price_data.csv')
hp_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
observed_table = pd.crosstab(hp_df['MSZoning'],hp_df['Street'])

# %%
pvalue = chi2_contingency(observed_table)[1]
if pvalue < 0.05:
    print('corelated')
else:
    print('not')
# Out:
# corelated

# %%
#hp_df['MSZoning'] hp_df['SalePrice']
values_column = hp_df['MSZoning'].unique()
output = [hp_df[hp_df[cat]] == hp_df['SalePrice']for cat in values_column]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RL'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
x = hp_df['MSZoning'].value_counts().index

# %%
output = f_oneway(*[ hp_df[hp_df['MSZoning'] == i]['SalePrice'] for i in x ])[1]
output
# Out:
# 8.817633866272648e-35
